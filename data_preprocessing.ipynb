# %%
import re
import os
import pandas as pd
from textblob import TextBlob 
from wordcloud import WordCloud

# %%
txt_folder = "E:/Dissertation/shumbam/#mentalhealthawareness"
file_contents_1 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
                content = file.read()
                file_contents_1.append(content)

# %%
file_contents_1
# Out:
# ['Today was a beautiful day, to have a good day 🍀\n\n#LGBTQ #GoodLifeProject #HealingJourney #SelfLove #PositiveVibes #GoodVibes\n #PerfectlyImperfect #BeYOUtiful #AdultingDoneRight  #MentalHealthMatters #MentalHeath\n#Healing #HealingQuotes\n\n#meditation #selfcare #health #mindfulness #wellness #motivation #inspiration #energy #peace #happiness #loveyourself #quotes #positivity #healthylifestyle #mentalhealthawareness #consciousness #gratitude\n',
# ...

# %%
txt_folder = "E:/Dissertation/shumbam/#loveyourself"
file_contents_2 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_2.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#mentalhealth"
file_contents_3 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_3.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#mentalhealthmatters"
file_contents_4 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_4.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#mentallillness"
file_contents_5 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_5.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#psychology"
file_contents_6 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_6.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#selfcare"
file_contents_7 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_7.append(content)

# %%
txt_folder = "E:/Dissertation/shumbam/#wellbeing"
file_contents_8 = []

for filename in os.listdir(txt_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(txt_folder, filename), "r", encoding="utf-8") as file:
            content = file.read()
            file_contents_8.append(content)

# %%
df = pd.concat([pd.Series(file_contents_1),
                    pd.Series(file_contents_2),
                    pd.Series(file_contents_3),
                    pd.Series(file_contents_4),
                    pd.Series(file_contents_5),
                    pd.Series(file_contents_6),
                    pd.Series(file_contents_7),
                    pd.Series(file_contents_8)], axis=0, ignore_index=True)

# %%
df.to_csv("post.csv",index=False)
